# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from library.sb_utils import save_file

# %%
# the supplied CSV data file is the raw_data directory
spotify_data = pd.read_csv("C:\\Users\\thomp\\Documents\\JT-Springboard\\Capstone 2\\raw_data\\spotify_most_streamed_songs.csv")
os.getcwd()
# Out:
# 'C:\\Users\\thomp\\Documents\\JT-Springboard\\Capstone 2'

# %%
spotify_data.info
# Out:
# <bound method DataFrame.info of                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 0                  147  141381703                  43  ...    B  Major
# 1                   48  133716286                  48  ...   C#  Major
# 2                  113  140003974                  94  ...    F  Major
# 3                  100  800840817                 116  ...    A  Major
# 4                   50  303236322                  84  ...    A  Minor
# ..                 ...        ...                 ...  ...  ...    ...
# 948                  0   91473363                  61  ...    A  Major
# 949                  0  121871870                   4  ...   F#  Major
# 950                  0   73513683                   2  ...   C#  Major
# 951                  0  133895612                  29  ...   C#  Major
# 952                  2   96007391                  27  ...    E  Minor
#
#      danceability_% valence_%  energy_% acousticness_% instrumentalness_%  \
# 0                80        89        83             31                  0
# 1                71        61        74              7                  0
# 2                51        32        53             17                  0
# 3                55        58        72             11                  0
# 4                65        23        80             14                 63
# ..              ...       ...       ...            ...                ...
# 948              60        24        39             57                  0
# 949              42         7        24             83                  1
# 950              80        81        67              4                  0
# 951              82        67        77              8                  0
# 952              61        32        67             15                  0
#
#      liveness_%  speechiness_%  \
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
#                                              cover_url
# 0                                            Not Found
# 1    https://i.scdn.co/image/ab67616d0000b2730656d5...
# 2    https://i.scdn.co/image/ab67616d0000b273e85259...
# 3    https://i.scdn.co/image/ab67616d0000b273e787cf...
# 4    https://i.scdn.co/image/ab67616d0000b273ab5c9c...
# ..                                                 ...
# 948  https://i.scdn.co/image/ab67616d0000b2730f5397...
# 949  https://i.scdn.co/image/ab67616d0000b273e0b60c...
# 950                                          Not Found
# 951                                          Not Found
# 952  https://i.scdn.co/image/ab67616d0000b273992a1f...
#
# [953 rows x 25 columns]>

# %%
spotify_data.head
# Out:
# <bound method NDFrame.head of                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 0                  147  141381703                  43  ...    B  Major
# 1                   48  133716286                  48  ...   C#  Major
# 2                  113  140003974                  94  ...    F  Major
# 3                  100  800840817                 116  ...    A  Major
# 4                   50  303236322                  84  ...    A  Minor
# ..                 ...        ...                 ...  ...  ...    ...
# 948                  0   91473363                  61  ...    A  Major
# 949                  0  121871870                   4  ...   F#  Major
# 950                  0   73513683                   2  ...   C#  Major
# 951                  0  133895612                  29  ...   C#  Major
# 952                  2   96007391                  27  ...    E  Minor
#
#      danceability_% valence_%  energy_% acousticness_% instrumentalness_%  \
# 0                80        89        83             31                  0
# 1                71        61        74              7                  0
# 2                51        32        53             17                  0
# 3                55        58        72             11                  0
# 4                65        23        80             14                 63
# ..              ...       ...       ...            ...                ...
# 948              60        24        39             57                  0
# 949              42         7        24             83                  1
# 950              80        81        67              4                  0
# 951              82        67        77              8                  0
# 952              61        32        67             15                  0
#
#      liveness_%  speechiness_%  \
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
#                                              cover_url
# 0                                            Not Found
# 1    https://i.scdn.co/image/ab67616d0000b2730656d5...
# 2    https://i.scdn.co/image/ab67616d0000b273e85259...
# 3    https://i.scdn.co/image/ab67616d0000b273e787cf...
# 4    https://i.scdn.co/image/ab67616d0000b273ab5c9c...
# ..                                                 ...
# 948  https://i.scdn.co/image/ab67616d0000b2730f5397...
# 949  https://i.scdn.co/image/ab67616d0000b273e0b60c...
# 950                                          Not Found
# 951                                          Not Found
# 952  https://i.scdn.co/image/ab67616d0000b273992a1f...
#
# [953 rows x 25 columns]>

# %%
spotify_data.head(100)
# Out:
#                              track_name     artist(s)_name  artist_count  \
# 0   Seven (feat. Latto) (Explicit Ver.)   Latto, Jung Kook             2
# 1                                  LALA        Myke Towers             1
# 2                               vampire     Olivia Rodrigo             1
# 3                          Cruel Summer       Taylor Swift             1
# 4                        WHERE SHE GOES          Bad Bunny             1
# ..                                  ...                ...           ...
# 95          All My Life (feat. J. Cole)  J. Cole, Lil Durk             2
# 96                    Say Yes To Heaven       Lana Del Rey             1
# 97                               Snooze                SZA             1
# 98                   Summertime Sadness       Lana Del Rey             1
# 99                             Take Two                BTS             1
#
#     released_year  released_month  released_day  in_spotify_playlists  \
# 0            2023               7            14                   553
# 1            2023               3            23                  1474
# 2            2023               6            30                  1397
# 3            2019               8            23                  7858
# 4            2023               5            18                  3133
# ..            ...             ...           ...                   ...
# 95           2023               5            12                  2175
# 96           2023               3            17                  2000
# 97           2022              12             9                  2839
# 98           2011               1             1                 20333
# 99           2023               6             9                   674
#
#     in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 0                 147  141381703                  43  ...    B  Major
# 1                  48  133716286                  48  ...   C#  Major
# 2                 113  140003974                  94  ...    F  Major
# 3                 100  800840817                 116  ...    A  Major
# 4                  50  303236322                  84  ...    A  Minor
# ..                ...        ...                 ...  ...  ...    ...
# 95                 23  144565150                  69  ...   D#  Major
# 96                 46  127567540                  49  ...   F#  Minor
# 97                 25  399686758                  58  ...    F  Major
# 98                 52  983637508                  89  ...   C#  Minor
# 99                 47  118482347                  20  ...    G  Major
#
#     danceability_% valence_%  energy_% acousticness_% instrumentalness_%  \
# 0               80        89        83             31                  0
# 1               71        61        74              7                  0
# 2               51        32        53             17                  0
# 3               55        58        72             11                  0
# 4               65        23        80             14                 63
# ..             ...       ...       ...            ...                ...
# 95              83        69        44             15                  0
# 96              49        17        35             71                  9
# 97              56        39        55             14                  0
# 98              56        24        66              7                  0
# 99              62        57        59              3                  0
#
#     liveness_%  speechiness_%  \
# 0            8              4
# 1           10              4
# 2           31              6
# 3           11             15
# 4           11              6
# ..         ...            ...
# 95          10             33
# 96          11              3
# 97          11             13
# 98          12              3
# 99          38              3
#
#                                             cover_url
# 0                                           Not Found
# 1   https://i.scdn.co/image/ab67616d0000b2730656d5...
# 2   https://i.scdn.co/image/ab67616d0000b273e85259...
# 3   https://i.scdn.co/image/ab67616d0000b273e787cf...
# 4   https://i.scdn.co/image/ab67616d0000b273ab5c9c...
# ..                                                ...
# 95                                          Not Found
# 96  https://i.scdn.co/image/ab67616d0000b273aa2770...
# 97  https://i.scdn.co/image/ab67616d0000b27370dbc9...
# 98  https://i.scdn.co/image/ab67616d0000b273f894be...
# 99  https://i.scdn.co/image/ab67616d0000b2738a701e...
#
# [100 rows x 25 columns]
